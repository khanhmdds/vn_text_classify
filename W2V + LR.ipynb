# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install transformers==2.1.0
# !pip install gensim==4.1.2
# !pip3 install --user underthesea

# !pip install pyvi
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting gensim==4.1.2
#   Downloading gensim-4.1.2-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (24.1 MB)
#      |████████████████████████████████| 24.1 MB 19 kB/s
# Requirement already satisfied: smart-open>=1.8.1 in /usr/local/lib/python3.7/dist-packages (from gensim==4.1.2) (5.2.1)
# Requirement already satisfied: scipy>=0.18.1 in /usr/local/lib/python3.7/dist-packages (from gensim==4.1.2) (1.7.3)
# Requirement already satisfied: numpy>=1.17.0 in /usr/local/lib/python3.7/dist-packages (from gensim==4.1.2) (1.21.6)
# Installing collected packages: gensim
#   Attempting uninstall: gensim
#     Found existing installation: gensim 3.6.0
#     Uninstalling gensim-3.6.0:
#       Successfully uninstalled gensim-3.6.0
# Successfully installed gensim-4.1.2
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting underthesea
#   Downloading underthesea-1.3.4-py3-none-any.whl (7.6 MB)
#      |████████████████████████████████| 7.6 MB 4.1 MB/s
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from underthesea) (2.23.0)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.7/dist-packages (from underthesea) (6.0)
# Collecting python-crfsuite>=0.9.6
#   Downloading python_crfsuite-0.9.8-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (965 kB)
#      |████████████████████████████████| 965 kB 42.5 MB/s
# Requirement already satisfied: nltk in /usr/local/lib/python3.7/dist-packages (from underthesea) (3.7)
# Collecting unidecode
#   Downloading Unidecode-1.3.4-py3-none-any.whl (235 kB)
#      |████████████████████████████████| 235 kB 67.1 MB/s
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from underthesea) (1.0.2)
# Collecting underthesea-core==0.0.4_alpha.10
#   Downloading underthesea_core-0.0.4_alpha.10-cp37-cp37m-manylinux2010_x86_64.whl (581 kB)
#      |████████████████████████████████| 581 kB 67.6 MB/s
# Requirement already satisfied: Click>=6.0 in /usr/local/lib/python3.7/dist-packages (from underthesea) (7.1.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from underthesea) (1.1.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from underthesea) (4.64.1)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.7/dist-packages (from nltk->underthesea) (2022.6.2)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->underthesea) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->underthesea) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->underthesea) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->underthesea) (2022.6.15)
# Requirement already satisfied: numpy>=1.14.6 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->underthesea) (1.21.6)
# Requirement already satisfied: scipy>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->underthesea) (1.7.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->underthesea) (3.1.0)
# Installing collected packages: unidecode, underthesea-core, python-crfsuite, underthesea
#   WARNING: The script unidecode is installed in '/root/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script underthesea is installed in '/root/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# Successfully installed python-crfsuite-0.9.8 underthesea-1.3.4 underthesea-core-0.0.4a10 unidecode-1.3.4

# %%
#from pyvi import ViTokenizer, ViPosTagger
import regex as re
from underthesea import word_tokenize
import numpy as np
import pandas as pd
import gensim
import sklearn
import tensorflow as tf
from sklearn import svm
from sklearn.model_selection import train_test_split
#from sklearn.decomposition import TruncatedSVD
from sklearn.metrics import classification_report
from sklearn.feature_extraction.text import TfidfVectorizer
from tensorflow.keras.layers import *
from keras.layers import *
from keras.preprocessing.text import Tokenizer
from keras.models import Model
from keras.metrics import sparse_categorical_accuracy
from tensorflow.keras.optimizers import Adam
# Chia tập train/test
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

# %%
# Thống kê số lượng data theo nhãn
count = {}
for line in open('/content/drive/MyDrive/KhanhMD/Data/news_categories.csv'):
    key = line.split()[0]
    count[key] = count.get(key, 0) + 1

for key in count:
    print(key, count[key])
# Out:
# __label__thể_thao 2611
# __label__âm_nhạc 2595
# __label__nhịp_sống 2613
# __label__công_nghệ 2595
# __label__thời_sự 2607
# __label__thế_giới 2602
# __label__thời_trang 2596
# __label__du_lịch 2593
# __label__sống_trẻ 2602
# __label__giáo_dục 2603
# __label__kinh_doanh 2597
# __label__pháp_luật 2592
# __label__giải_trí 2604
# __label__phim_ảnh 2596
# __label__xe_360 2602
# __label__ẩm_thực 2482
# __label__xuất_bản 2599
# __label__sức_khỏe 2589

# %%
# Thống kê các word xuất hiện ở tất cả các nhãn
total_label = 18
vocab = {}
label_vocab = {}
for line in open('/content/drive/MyDrive/KhanhMD/Data/news_categories.csv'):
    words = line.split()
    # lưu ý từ đầu tiên là nhãn
    label = words[0]
    if label not in label_vocab:
        label_vocab[label] = {}
    for word in words[1:]:
        label_vocab[label][word] = label_vocab[label].get(word, 0) + 1
        if word not in vocab:
            vocab[word] = set()
        vocab[word].add(label)

# count = {}
# for word in vocab:
#     if len(vocab[word]) == total_label:
#         count[word] = min([label_vocab[x][word] for x in label_vocab])
        
# sorted_count = sorted(count, key=count.get, reverse=True)
# for word in sorted_count[:100]:
#     print(word, count[word])
text = []
label = []

for line in open('/content/drive/MyDrive/KhanhMD/Data/news_categories.csv'):
    words = line.strip().split()
    label.append(words[0])
    text.append(' '.join(words[1:]))

# %%
label_encoder = LabelEncoder()
label_encoder.fit(label)
encode_label = label_encoder.transform(label)

# %%
import pandas as pd
df = pd.DataFrame(text, columns=["text"])
df.to_csv('text.csv', index=False)

# %%
rd = pd.read_csv('text.csv')
rd[:10]
# Out:
#                                                 text
# 0  sanchez không dự trận khai màn nh anh cùng ars...
# 1  những sao việt hóa_thân thành phó nháy trong m...
# 2  vợ phải quỳ gối mới được nói_chuyện cười zing ...
# 3  lumia 520 sẽ có giá 3 9 triệu đồng tại việt_na...
# 4  hà_nội t t chốt danh_sách dự afc cup thể_thao ...
# 5  vụ xe điên gây tai_nạn ở sài_gòn tài_xế bị tâm...
# 6  lính nga nhảy_dù xuống tảng băng trôi trên bắc...
# 7  ngắm vĩnh_thụy đầy chất chơi thời_trang zing v...
# 8  bố_mẹ dừng tàu lượn siêu_tốc vì lo cho con_gái...
# 9  cụ bà 84 tuổi đặc_trị bệnh chó dại thời_sự zin...

# %%
import pandas as pd
df = pd.DataFrame(encode_label, columns=["label"])
df.to_csv('label.csv', index=False)

# %%
lb = pd.read_csv('label.csv')
lb[:10]
# Out:
#    label
# 0     11
# 1     16
# 2      5
# 3      0
# 4     11
# 5     12
# 6     10
# 7     13
# 8      1
# 9     12

# %%
a = pd.read_csv("label.csv")
b = pd.read_csv("text.csv")
df_merge_col = pd.merge(a, b,left_index=True, right_index=True, how='outer')
df_merge_col.to_csv("data.csv", index=False)

# %%
c = pd.read_csv("data.csv")
c[:10]
# Out:
#    label                                               text
# 0     11  sanchez không dự trận khai màn nh anh cùng ars...
# 1     16  những sao việt hóa_thân thành phó nháy trong m...
# 2      5  vợ phải quỳ gối mới được nói_chuyện cười zing ...
# 3      0  lumia 520 sẽ có giá 3 9 triệu đồng tại việt_na...
# 4     11  hà_nội t t chốt danh_sách dự afc cup thể_thao ...
# 5     12  vụ xe điên gây tai_nạn ở sài_gòn tài_xế bị tâm...
# 6     10  lính nga nhảy_dù xuống tảng băng trôi trên bắc...
# 7     13  ngắm vĩnh_thụy đầy chất chơi thời_trang zing v...
# 8      1  bố_mẹ dừng tàu lượn siêu_tốc vì lo cho con_gái...
# 9     12  cụ bà 84 tuổi đặc_trị bệnh chó dại thời_sự zin...

# %%
df = c.copy()
df[:10]
# Out:
#    label                                               text
# 0     11  sanchez không dự trận khai màn nh anh cùng ars...
# 1     16  những sao việt hóa_thân thành phó nháy trong m...
# 2      5  vợ phải quỳ gối mới được nói_chuyện cười zing ...
# 3      0  lumia 520 sẽ có giá 3 9 triệu đồng tại việt_na...
# 4     11  hà_nội t t chốt danh_sách dự afc cup thể_thao ...
# 5     12  vụ xe điên gây tai_nạn ở sài_gòn tài_xế bị tâm...
# 6     10  lính nga nhảy_dù xuống tảng băng trôi trên bắc...
# 7     13  ngắm vĩnh_thụy đầy chất chơi thời_trang zing v...
# 8      1  bố_mẹ dừng tàu lượn siêu_tốc vì lo cho con_gái...
# 9     12  cụ bà 84 tuổi đặc_trị bệnh chó dại thời_sự zin...

# %%
df.shape
# Out:
# (46678, 2)

# %%
#tok = Tokenizer()
# lst_corpus = []
# for string in df['text']:
#    lst_words = string.split()
#    lst_grams = [" ".join(lst_words[i:i+1]) for i in range(0, len(lst_words), 1)]
#    lst_corpus.append(lst_grams)

# print(len(lst_corpus))

# %%
split_text = [s.split() for s in text]

# %%
w2v = gensim.models.Word2Vec(split_text,
                                   vector_size=100,
                                   window=5,
                                   min_count=1)
words = set(w2v.wv.index_to_key)

# %%
w2v.train(split_text ,epochs=10,total_examples=len(split_text))
# Out:
# WARNING:gensim.models.word2vec:Effective 'alpha' higher than previous training cycles
# (227650919, 256614670)

# %%
vocab=w2v.wv.key_to_index
print("The total number of words are : ",len(vocab))
# Out:
# The total number of words are :  233702

# %%
vocab=list(vocab.keys())

# %%
word_vec_dict={}
for word in vocab:
  word_vec_dict[word]=w2v.wv.get_vector(word)
print(len(word_vec_dict))
# Out:
# 233702

# %%
# maxi=-1
# for i,rev in enumerate(df['text']):
#     tokens=rev.split()
#     if(len(tokens)>maxi):
#         maxi=len(tokens)
# print(maxi)

# %%
tok = Tokenizer()
tok.fit_on_texts(df['text'])
vocab_size = len(tok.word_index) + 1
encd_rev = tok.texts_to_sequences(df['text'])

# %%
max_rev_len=2000  # max lenght of a review
vocab_size = len(tok.word_index) + 1  # total no of words
embed_dim=100

# %%
from keras.preprocessing.sequence import pad_sequences
pad_rev= pad_sequences(encd_rev, maxlen=max_rev_len, padding='post')
pad_rev.shape
# Out:
# (46678, 2000)

# %%
pad_rev
# Out:
# array([[4729,   10,  226, ...,    0,    0,    0],
#        [  12,  254,   58, ...,    0,    0,    0],
#        [ 490,   54, 2801, ...,    0,    0,    0],
#        ...,
#        [ 225,  298,  130, ...,    0,    0,    0],
#        [2610,  298,  692, ...,    0,    0,    0],
#        [  39, 1143, 7507, ...,    0,    0,    0]], dtype=int32)

# %%
embed_matrix=np.zeros(shape=(vocab_size,embed_dim))
for word,i in tok.word_index.items():
  embed_vector=word_vec_dict.get(word)
  if embed_vector is not None:  # word is in the vocabulary learned by the w2v model
    embed_matrix[i]=embed_vector

# %%
embed_matrix.shape
# Out:
# (93363, 100)

# %%
import keras
import keras.utils
from keras import utils as np_utils
import tensorflow as tf
from tensorflow.keras.layers import Dense, LSTM
from tensorflow.keras.models import Model
from tensorflow.keras.models import Sequential
from keras.utils import np_utils
sklearn.model_selection.train_test_split
# Out:
# <function sklearn.model_selection._split.train_test_split(*arrays, test_size=None, train_size=None, random_state=None, shuffle=True, stratify=None)>

# %%
# !pip install np_utils
from keras.utils.np_utils import to_categorical

# %%
# Y=keras.utils.to_categorical(df['label'])
# Y.shape
from keras import utils as np_utils
Y=keras.utils.np_utils.to_categorical(df['label'])  # one hot target as required by NN.

# %%
X_train, X_test, y_train, y_test = train_test_split(pad_rev, Y, test_size=0.1, random_state=42)

X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=42) # 0.25 x 0.8 = 0.2

# %%
from keras.initializers import Constant
from keras.layers import ReLU
from keras.layers import Dropout
model=Sequential()
model.add(Embedding(input_dim=vocab_size,output_dim=embed_dim,input_length=max_rev_len,embeddings_initializer=Constant(embed_matrix)))
# model.add(Bidirectional(LSTM(128)))
model.add(Flatten())
# model.add(Dense(64,activation='relu',kernel_regularizer='l2'))
# model.add(Dropout(0.2))

#model.add(Dense(1024,activation='relu'))
# model.add(Dense(64,activation='relu',kernel_regularizer='l2'))
# model.add(Dropout(0.20))
# model.add(Dense(32,activation='relu',kernel_regularizer='l2'))
#model.add(Dense(32,activation='relu',kernel_regularizer='l2'))
# model.add(Dense(1,activation='relu'))
# model.add(Dense(16,activation='relu'))
# model.add(Dropout(0.5))
model.add(Dense(18,activation='softmax',kernel_regularizer='l1'))

# %%
model.summary()
# Out:
# Model: "sequential_23"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_23 (Embedding)    (None, 2000, 100)         9336300
#
#  flatten_23 (Flatten)        (None, 200000)            0
#
#  dense_23 (Dense)            (None, 18)                3600018
#
# =================================================================
# Total params: 12,936,318
# Trainable params: 12,936,318
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow import keras
from keras import optimizers

# %%
model.compile(optimizer=keras.optimizers.RMSprop(lr=0.0001),loss='categorical_crossentropy',metrics=['accuracy'])
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/rmsprop.py:130: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(RMSprop, self).__init__(name, **kwargs)

# %%
epochs=30
batch_size=64

# %%
from keras.callbacks import EarlyStopping
from keras.callbacks import ModelCheckpoint
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=5)
mc = ModelCheckpoint('best_model.h5', monitor='val_loss', mode='min', verbose=1, save_best_only=True)

# %%
model.fit(X_train,y_train,epochs=epochs,batch_size=batch_size,validation_data=(X_val,y_val),callbacks=[es, mc])
# Out:
# Epoch 1/30
# 521/526 [============================>.] - ETA: 0s - loss: 14.2599 - accuracy: 0.7148
# Epoch 1: val_loss improved from inf to 5.32533, saving model to best_model.h5
# 526/526 [==============================] - 14s 25ms/step - loss: 14.1920 - accuracy: 0.7156 - val_loss: 5.3253 - val_accuracy: 0.7680
# Epoch 2/30
# 526/526 [==============================] - ETA: 0s - loss: 5.4619 - accuracy: 0.8299
# Epoch 2: val_loss did not improve from 5.32533
# 526/526 [==============================] - 6s 11ms/step - loss: 5.4619 - accuracy: 0.8299 - val_loss: 6.1807 - val_accuracy: 0.7483
# Epoch 3/30
# 525/526 [============================>.] - ETA: 0s - loss: 5.2362 - accuracy: 0.8496
# Epoch 3: val_loss did not improve from 5.32533
# 526/526 [==============================] - 6s 11ms/step - loss: 5.2362 - accuracy: 0.8496 - val_loss: 5.5093 - val_accuracy: 0.7246
# Epoch 4/30
# 522/526 [============================>.] - ETA: 0s - loss: 5.0922 - accuracy: 0.8585
# Epoch 4: val_loss did not improve from 5.32533
# 526/526 [==============================] - 6s 11ms/step - loss: 5.0913 - accuracy: 0.8586 - val_loss: 5.6209 - val_accuracy: 0.7949
# Epoch 5/30
# 522/526 [============================>.] - ETA: 0s - loss: 5.0024 - accuracy: 0.8675
# Epoch 5: val_loss improved from 5.32533 to 5.15191, saving model to best_model.h5
# 526/526 [==============================] - 12s 22ms/step - loss: 5.0012 - accuracy: 0.8675 - val_loss: 5.1519 - val_accuracy: 0.8193
# Epoch 6/30
# 523/526 [============================>.] - ETA: 0s - loss: 4.9313 - accuracy: 0.8704
# Epoch 6: val_loss improved from 5.15191 to 5.07689, saving model to best_model.h5
# 526/526 [==============================] - 13s 24ms/step - loss: 4.9326 - accuracy: 0.8703 - val_loss: 5.0769 - val_accuracy: 0.8492
# Epoch 7/30
# 523/526 [============================>.] - ETA: 0s - loss: 4.8683 - accuracy: 0.8749
# Epoch 7: val_loss did not improve from 5.07689
# 526/526 [==============================] - 6s 11ms/step - loss: 4.8696 - accuracy: 0.8747 - val_loss: 7.2811 - val_accuracy: 0.7424
# Epoch 8/30
# 524/526 [============================>.] - ETA: 0s - loss: 4.8410 - accuracy: 0.8792
# Epoch 8: val_loss improved from 5.07689 to 5.02774, saving model to best_model.h5
# 526/526 [==============================] - 12s 22ms/step - loss: 4.8411 - accuracy: 0.8792 - val_loss: 5.0277 - val_accuracy: 0.8375
# Epoch 9/30
# 521/526 [============================>.] - ETA: 0s - loss: 4.7876 - accuracy: 0.8799
# Epoch 9: val_loss did not improve from 5.02774
# 526/526 [==============================] - 6s 11ms/step - loss: 4.7856 - accuracy: 0.8799 - val_loss: 5.6907 - val_accuracy: 0.8286
# Epoch 10/30
# 523/526 [============================>.] - ETA: 0s - loss: 4.7483 - accuracy: 0.8841
# Epoch 10: val_loss did not improve from 5.02774
# 526/526 [==============================] - 6s 11ms/step - loss: 4.7484 - accuracy: 0.8838 - val_loss: 5.2469 - val_accuracy: 0.8040
# Epoch 11/30
# 524/526 [============================>.] - ETA: 0s - loss: 4.7127 - accuracy: 0.8862
# Epoch 11: val_loss improved from 5.02774 to 4.86972, saving model to best_model.h5
# 526/526 [==============================] - 13s 24ms/step - loss: 4.7126 - accuracy: 0.8862 - val_loss: 4.8697 - val_accuracy: 0.8043
# Epoch 12/30
# 525/526 [============================>.] - ETA: 0s - loss: 4.6666 - accuracy: 0.8873
# Epoch 12: val_loss improved from 4.86972 to 4.84944, saving model to best_model.h5
# 526/526 [==============================] - 12s 22ms/step - loss: 4.6666 - accuracy: 0.8873 - val_loss: 4.8494 - val_accuracy: 0.8672
# Epoch 13/30
# 526/526 [==============================] - ETA: 0s - loss: 4.6269 - accuracy: 0.8918
# Epoch 13: val_loss improved from 4.84944 to 4.84438, saving model to best_model.h5
# 526/526 [==============================] - 13s 24ms/step - loss: 4.6269 - accuracy: 0.8918 - val_loss: 4.8444 - val_accuracy: 0.8618
# Epoch 14/30
# 522/526 [============================>.] - ETA: 0s - loss: 4.5980 - accuracy: 0.8925
# Epoch 14: val_loss improved from 4.84438 to 4.76966, saving model to best_model.h5
# 526/526 [==============================] - 12s 22ms/step - loss: 4.5979 - accuracy: 0.8924 - val_loss: 4.7697 - val_accuracy: 0.8302
# Epoch 15/30
# 525/526 [============================>.] - ETA: 0s - loss: 4.5739 - accuracy: 0.8945
# Epoch 15: val_loss improved from 4.76966 to 4.27561, saving model to best_model.h5
# 526/526 [==============================] - 12s 22ms/step - loss: 4.5738 - accuracy: 0.8945 - val_loss: 4.2756 - val_accuracy: 0.8813
# Epoch 16/30
# 525/526 [============================>.] - ETA: 0s - loss: 4.5269 - accuracy: 0.8971
# Epoch 16: val_loss did not improve from 4.27561
# 526/526 [==============================] - 6s 11ms/step - loss: 4.5269 - accuracy: 0.8972 - val_loss: 4.7953 - val_accuracy: 0.8674
# Epoch 17/30
# 526/526 [==============================] - ETA: 0s - loss: 4.4996 - accuracy: 0.9001
# Epoch 17: val_loss did not improve from 4.27561
# 526/526 [==============================] - 6s 11ms/step - loss: 4.4996 - accuracy: 0.9001 - val_loss: 4.9131 - val_accuracy: 0.8687
# Epoch 18/30
# 526/526 [==============================] - ETA: 0s - loss: 4.4787 - accuracy: 0.9006
# Epoch 18: val_loss did not improve from 4.27561
# 526/526 [==============================] - 6s 11ms/step - loss: 4.4787 - accuracy: 0.9006 - val_loss: 5.1197 - val_accuracy: 0.8697
# Epoch 19/30
# 524/526 [============================>.] - ETA: 0s - loss: 4.4483 - accuracy: 0.9011
# Epoch 19: val_loss did not improve from 4.27561
# 526/526 [==============================] - 6s 11ms/step - loss: 4.4482 - accuracy: 0.9010 - val_loss: 4.3379 - val_accuracy: 0.8591
# Epoch 20/30
# 524/526 [============================>.] - ETA: 0s - loss: 4.4181 - accuracy: 0.9045
# Epoch 20: val_loss improved from 4.27561 to 3.97341, saving model to best_model.h5
# 526/526 [==============================] - 13s 24ms/step - loss: 4.4174 - accuracy: 0.9046 - val_loss: 3.9734 - val_accuracy: 0.8854
# Epoch 21/30
# 523/526 [============================>.] - ETA: 0s - loss: 4.3897 - accuracy: 0.9073
# Epoch 21: val_loss did not improve from 3.97341
# 526/526 [==============================] - 6s 11ms/step - loss: 4.3898 - accuracy: 0.9073 - val_loss: 4.3558 - val_accuracy: 0.8874
# Epoch 22/30
# 525/526 [============================>.] - ETA: 0s - loss: 4.3616 - accuracy: 0.9086
# Epoch 22: val_loss did not improve from 3.97341
# 526/526 [==============================] - 6s 11ms/step - loss: 4.3616 - accuracy: 0.9086 - val_loss: 4.4166 - val_accuracy: 0.8806
# Epoch 23/30
# 524/526 [============================>.] - ETA: 0s - loss: 4.3325 - accuracy: 0.9093
# Epoch 23: val_loss did not improve from 3.97341
# 526/526 [==============================] - 6s 11ms/step - loss: 4.3333 - accuracy: 0.9092 - val_loss: 4.8221 - val_accuracy: 0.8816
# Epoch 24/30
# 522/526 [============================>.] - ETA: 0s - loss: 4.3122 - accuracy: 0.9107
# Epoch 24: val_loss did not improve from 3.97341
# 526/526 [==============================] - 6s 11ms/step - loss: 4.3123 - accuracy: 0.9106 - val_loss: 4.7352 - val_accuracy: 0.8885
# Epoch 25/30
# 522/526 [============================>.] - ETA: 0s - loss: 4.2842 - accuracy: 0.9128
# Epoch 25: val_loss did not improve from 3.97341
# 526/526 [==============================] - 6s 11ms/step - loss: 4.2842 - accuracy: 0.9129 - val_loss: 5.7033 - val_accuracy: 0.8360
# Epoch 25: early stopping

# %%
modelx = keras.models.load_model('best_model.h5')

# %%
y_pred_one_hot_encoded = (modelx.predict(X_test)> 0.5).astype("float")
#y_pred_test = np.array(tf.argmax(y_pred_one_hot_encoded, axis=1))

# %%
print(classification_report(y_test, y_pred_one_hot_encoded))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.76      0.86       268
#            1       1.00      0.72      0.83       267
#            2       0.98      0.56      0.71       270
#            3       0.97      0.73      0.83       228
#            4       1.00      0.46      0.63       270
#            5       0.98      0.62      0.76       252
#            6       0.98      0.86      0.91       250
#            7       0.99      0.77      0.87       270
#            8       1.00      0.60      0.75       249
#            9       0.93      0.86      0.89       252
#           10       0.96      0.63      0.76       258
#           11       1.00      0.69      0.82       264
#           12       0.99      0.75      0.86       241
#           13       0.99      0.63      0.77       277
#           14       0.99      0.81      0.89       262
#           15       1.00      0.55      0.71       247
#           16       0.99      0.80      0.89       290
#           17       0.98      0.72      0.83       253
#
#    micro avg       0.98      0.69      0.81      4668
#    macro avg       0.98      0.69      0.81      4668
# weighted avg       0.98      0.69      0.81      4668
#  samples avg       0.69      0.69      0.69      4668
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in samples with no predicted labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
modelx.evaluate(X_test, y_test, batch_size=64)
# Out:
# 73/73 [==============================] - 0s 3ms/step - loss: 4.1418 - accuracy: 0.8464
# [4.1417717933654785, 0.846401035785675]
